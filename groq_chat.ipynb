# %% [markdown]
# loading environments

# %%
import os
from groq import Groq
from dotenv import load_dotenv
load_dotenv()

groq_api_key = os.getenv("GROQ_API_KEY")
'''os.environ["LANGCHAIN_API_KEY"] = os.getenv('LANGCHAIN_API_KEY')
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = os.getenv("LANGCHAIN_PROJECT")'''
# Out:
# 'os.environ["LANGCHAIN_API_KEY"] = os.getenv(\'LANGCHAIN_API_KEY\')\nos.environ["LANGCHAIN_TRACING_V2"] = "true"\nos.environ["LANGCHAIN_PROJECT"] = os.getenv("LANGCHAIN_PROJECT")'

# %%
from langchain_groq import ChatGroq
model = ChatGroq(model = "Llama 3.3 70B", api_key = groq_api_key)

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
        SystemMessage(content= "You are a expert in elden ring and your job is to guide the players who have any questions about the game"),
        HumanMessage(content= "I have defeated Radhan, don't know what to do next")
]

# %%
model.invoke(messages)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 model.invoke(messages)
#
# File c:\Users\Shubham\Desktop\Data Science Prep\Generative AI Course\Langchain\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
# ...

# %%
import os
from dotenv import load_dotenv

load_dotenv()

key = os.getenv("GROQ_API_KEY")
print(key[:8] if key else "No key found")
# Out:
# sk-uvwx5

# %%
from groq import Groq
import os
from dotenv import load_dotenv

load_dotenv()

api_key = os.getenv("GROQ_API_KEY")
print(api_key[:10])  # Should print gsk_...

client = Groq(api_key=api_key)

response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {"role": "user", "content": "Hello"}
    ]
)

print(response.choices[0].message.content)
# Out:
# sk-uvwx567
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[102], line 12
#       8 print(api_key[:10])  # Should print gsk_...
#       9
#      10 client = Groq(api_key=api_key)
#      11
# ---> 12 response = client.chat.completions.create(
#      13     model="llama-3.3-70b-versatile",
#      14     messages=[
#      15         {"role": "user", "content": "Hello"}
#
# ...
